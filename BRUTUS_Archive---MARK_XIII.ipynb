# %%
import schedule
import time
from gtts import gTTS
import os
from playsound import playsound
playsound('C:/Users/joeca/Desktop/Finance/FOREX/Hercules_Prototype_Mark_II/MP3s/startup.mp3')

# %%
import winsound
import numpy as np
import pandas as pd
import math
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sympy import *
init_printing()
import xlrd
from datetime import datetime as dt

# %%
from multiprocessing import Process
import json
from scipy.signal import argrelextrema
import pytz
import itertools
from itertools import combinations
from itertools import product
from itertools import groupby
from astropy.table import QTable, Table, Column
from astropy import units as u
from IPython.display import HTML

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import MetaTrader5 as mt5

# %%
if not mt5.initialize(path="C:/JoeC/MetaTrader 5/terminal64.exe",login=1045610, server="TradersWay-Demo",password="r5AH8znU"):
    print("initialize() failed, error code =",mt5.last_error())
    quit()

# %%
def brutus2(h,i,j,k,l,m,threshold,threshold2,RATE,RATE2,spy):
    
    riskusd = 5.00
            
    symbol_info = mt5.symbol_info(h)
    point = mt5.symbol_info(h).point
    quote = h[3:]

    if quote == "USD":
        exchange = 1.00
    elif quote == "AUD":
        exchange = mt5.symbol_info("AUDUSD").bid
        exchange = 1/exchange
    elif quote == "CAD":
        exchange = mt5.symbol_info("USDCAD").bid
    elif quote == "CHF":
        exchange = mt5.symbol_info("USDCHF").bid
    elif quote == "EUR":
        exchange = mt5.symbol_info("EURUSD").bid
        exchange = 1/exchange
    elif quote == "GBP":
        exchange = mt5.symbol_info("GBPUSD").bid
        exchange = 1/exchange
    elif quote == "JPY":
        exchange = mt5.symbol_info("USDJPY").bid
    elif quote == "NZD":
        exchange = mt5.symbol_info("NZDUSD").bid
        exchange = 1/exchange
    
    if quote == "JPY":
        stpips = abs(l - j)*100
        lot = round((((riskusd*exchange)/stpips)/10)/100,2)
    else:
        stpips = abs(l - j)*10000
        lot = round(((riskusd*exchange)/stpips)/10,2)
    
    if i == "LONG":
        price = mt5.symbol_info_tick(h).bid
        request = {
            "action": mt5.TRADE_ACTION_DEAL,
            "symbol": h,
            "volume": lot,
            "type": mt5.ORDER_TYPE_BUY,
            "price": price,
            "sl": l,
            "tp": k,
            "deviation": 20,
            "magic": 234000,
            "comment": "BRUTUS Mark V",
            "type_time": mt5.ORDER_TIME_GTC,
            "type_filling": mt5.ORDER_FILLING_IOC,
        }
        extraj = j + m
        selected=mt5.symbol_select(h,True)
        if not selected:
            print("Failed to select pair")
            mt5.shutdown()
            quit()
            spy = "NO"

    elif i == "SHORT":
        price = mt5.symbol_info_tick(h).ask

        request = {
            "action": mt5.TRADE_ACTION_DEAL,
            "symbol": h,
            "volume": lot,
            "type": mt5.ORDER_TYPE_SELL,
            "price": price,
            "sl": l,
            "tp": k,
            "deviation": 20,
            "magic": 234000,
            "comment": "BRUTUS Mark V",
            "type_time": mt5.ORDER_TIME_GTC,
            "type_filling": mt5.ORDER_FILLING_IOC,
        }
        extraj = j - m
        selected=mt5.symbol_select(h,True)

        if not selected:
            print("Failed to select pair")
            mt5.shutdown()
            quit()
            spy = "NO"

    lasttickb=mt5.symbol_info_tick(h).bid
    
    if lasttickb < extraj:
        RATE2 = RATE2 + 1
    else:
        RATE2 = 0
        
    if lasttickb < j:
        RATE = RATE + 1
    else:
        RATE = 0

    if RATE >= threshold:
        result = mt5.order_send(request)
        if result.retcode != mt5.TRADE_RETCODE_DONE:
            print("order_send failed, retcode={}".format(result.retcode))
            result_dict=result._asdict()
            for field in result_dict.keys():
                print("   {}={}".format(field,result_dict[field]))
                if field=="request":
                    traderequest_dict=result_dict[field]._asdict()
                    for tradereq_filed in traderequest_dict:
                        print("       traderequest: {}={}".format(tradereq_filed,traderequest_dict[tradereq_filed]))
        spy = "NO"
    elif RATE2 >= threshold2:
        result = mt5.order_send(request)
        if result.retcode != mt5.TRADE_RETCODE_DONE:
            print("order_send failed, retcode={}".format(result.retcode))
            result_dict=result._asdict()
            for field in result_dict.keys():
                print("   {}={}".format(field,result_dict[field]))
                if field=="request":
                    traderequest_dict=result_dict[field]._asdict()
                    for tradereq_filed in traderequest_dict:
                        print("       traderequest: {}={}".format(tradereq_filed,traderequest_dict[tradereq_filed]))
        spy = "NO"
    
    return RATE, RATE2, spy

# %%
## WATCHLIST = ['AUD/CAD', 'AUD/CHF', 'AUD/JPY', 'AUD/NZD', 'AUD/USD', 'CAD/CHF', 'CAD/JPY', 'CHF/JPY', 'EUR/AUD', 'EUR/CAD', 'EUR/CHF', 'EUR/GBP', 'EUR/JPY', 'EUR/NZD', 'EUR/USD', 'GBP/AUD', 'GBP/CAD', 'GBP/CHF', 'GBP/JPY', 'GBP/NZD', 'GBP/USD', 'NZD/CAD', 'NZD/CHF', 'NZD/JPY', 'NZD/USD', 'USD/CAD', 'USD/CHF', 'USD/JPY', 'XAG/USD', 'XAU/USD', 'BCH/USD', 'BTC/USD', 'EOS/USD', 'ETH/USD', 'LTC/USD', 'XLM/USD', 'XRP/USD']

## FOREX = ## WATCHLIST = ['AUDCAD','AUDCHF','AUDJPY','AUDNZD','AUDUSD','CADCHF','CADJPY','CHFJPY','EURAUD','EURCAD','EURCHF','EURGBP','EURJPY','EURNZD','EURUSD','GBPAUD','GBPCAD','GBPCHF','GBPJPY','GBPUSD','NZDCAD','NZDCHF','NZDJPY','NZDUSD','USDCAD','USDCHF','USDJPY']

def brutus():

    start = dt.now()
    purp = []
    pair = ['AUDCAD','AUDCHF','AUDJPY','AUDNZD','AUDUSD','CADCHF','CADJPY','CHFJPY','EURAUD','EURCAD','EURCHF','EURGBP','EURJPY','EURNZD','EURUSD','GBPAUD','GBPCAD','GBPCHF','GBPJPY','GBPUSD','NZDCAD','NZDCHF','NZDJPY','NZDUSD','USDCAD','USDCHF','USDJPY']
    l = 600
    lin = np.linspace(1,l,num=l)
    
    for x in pair:

        Srates = mt5.copy_rates_from_pos(x, mt5.TIMEFRAME_H8, 0, 600)

        S = pd.DataFrame(Srates)
        S['time']=pd.to_datetime(S['time'], unit='s')
        S = S.drop(columns=['tick_volume', 'spread', 'real_volume'])
        S = S.set_index('time')
        S = S.tz_localize('Etc/GMT-7')
        S = S.tz_convert('UTC')

        S = S.assign(MOVE=(S['close'] - S['open']))
        SAvgCandle = np.average(abs(S['MOVE']))
        STDCandle = np.std(abs(S['MOVE']))
        CP = S['close'].iloc[-1]
        scope = SAvgCandle*15
        SCM = SAvgCandle

        CNDL = (S.iloc[:, 3]) - (S.iloc[:, 0])
        S['CNDL'] = np.where(CNDL > 0, 1, -1)
        S = S.assign(INFL=S['CNDL'].ne(S['CNDL'].shift()))
        S = S[S.INFL != 0]
        S['INFL'] = S['CNDL']*-1
        S['LVL'] = np.where(S.INFL == 1, S.high, S.low)
        S = S.assign(SIZE=abs(S['LVL'] - (S['LVL'].shift(-1))))

        A = np.array(S.LVL)

        B = list(combinations(A, 2))
        Ba = np.array([x for x, y in B])
        B = np.array([abs(x - y) for x, y in B])
        Bb = np.array([np.where(x <= SCM, 1, 0) for x in B])

        T = list(zip(Ba,Bb))

        table = pd.DataFrame(T, columns=['a','b']).groupby('a').sum()
        table['max'] = table.b[(table.b.shift(1) < table.b) & (table.b.shift(-1) < table.b)]
        table = table.sort_values(['a'], ascending=False)
        table = table.rename(columns={'b': 'Pings'})
        table = table.fillna(0)
        table = table[table['max'] != 0]
        pingsavg = np.average(table['Pings'])
        table = table.assign(level=table.index)

        levels = list(table['level'])

        Drates = mt5.copy_rates_from_pos(x, mt5.TIMEFRAME_M5, 0, 600)
        D = pd.DataFrame(Drates)
        D['time']=pd.to_datetime(D['time'], unit='s')
        D = D.drop(columns=['tick_volume', 'spread', 'real_volume'])
        D = D.set_index('time')
        D = D.tz_localize('Etc/GMT-7')
        D = D.tz_convert('UTC')
        D = D.assign(MOVE=(D['close'] - D['open']))
        D = D.assign(STICK=(D['high'] - D['low']))
        D = D.assign(PSTICK=abs(D['MOVE']/D['STICK']))
        D['DIRECT'] = np.where(D.MOVE > 0, 'Bullish', 'Bearish')
        CM = np.average(abs(D['MOVE']))

        ANIMAL = []
        i = 0
        for t in lin: 
            if D.iloc[i,6] <= 1.1:
                if D.iloc[i,6] < 0.85:
                    if D.iloc[i,6] < 0.65:
                        if D.iloc[i,6] < 0.50:
                            if D.iloc[i,6] <= 0.30:
                                if D.iloc[i,6] <= 0.15:
                                    animal = 'Doji'
                                else:
                                    animal = 'Frog'
                            else:
                                animal = 'Cat'
                        else:
                            animal = 'Dog'
                    else:
                        animal = 'Horse'
                else:
                    animal = 'Shark'
            ANIMAL.append(animal)
            i = i + 1
        D['ANIMAL'] = ANIMAL

        GAUGE = []
        i = 0
        cndmid = (D.iloc[i,0]+D.iloc[i,3])/2
        stickmid = (D.iloc[i,1]+D.iloc[i,2])/2
        for t in lin: 
            if D.iloc[i,5] == 0:
                midpoint = D.iloc[i,0]
            else:
                midpoint = (cndmid - stickmid)/D.iloc[i,5]
            if midpoint >= 0.075:
                if midpoint >= 0.175:
                    if midpoint >= 0.25:
                        gauge = 'Top Saturated'
                    else:
                        gauge = 'Top Stacked'
                else:
                    gauge = 'Top Semi-Stacked'
            elif midpoint <= -0.075:
                if midpoint <= -0.175:
                    if midpoint <= -0.25:
                        gauge = 'Bottom Saturated'
                    else:
                        gauge = 'Bottom Stacked'
                else:
                    gauge = 'Bottom Semi-Stacked'
            else:
                gauge = 'Centered'
            GAUGE.append(gauge)
            i = i + 1
        D['GAUGE'] = GAUGE

        thh = 168
        tl = l - thh
        tlin = np.linspace(1,tl,num=tl)
        tlinb = np.linspace(1,thh,num=thh)
        TREND = []
        for t in tlinb:
            TREND.append(0)
        i = thh                                                                                       
        for t in tlin:
            ii = i - thh
            movetrend = np.sum(list(D.iloc[ii:i,4]))
            i = i + 1
            TREND.append(movetrend)
        D['TREND'] = TREND

        READING=[]
        i = 0
        for t in lin: 
            if D.iloc[i,10] < 0:
                if D.iloc[i,9] == 'Top Saturated':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'JACK'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'DIPPER'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'HAMMER'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'DRAGONFLY DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Top Stacked':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'JACK'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'SKILLET'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'MALLET'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'DRAGONFLY DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Top Semi-Stacked':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'PLUMP DOJI'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'LONG-LEG DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Centered':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'PLUMP DOJI'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'LONG-LEG DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Bottom Semi-Stacked':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'PLUMP DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Bottom Stacked':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'BOOST'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'BRAKE'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'BRAKE'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Bottom Saturated':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'BOOST'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'BRAKE'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'BRAKE'
                    else:
                        Read = D.iloc[i,8]
                else:
                    Read = D.iloc[i,8]
            elif D.iloc[i,10] > 0:
                if D.iloc[i,9] == 'Bottom Saturated':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'JACK'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'DIPPER'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'SHOOTING STAR'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'GRAVESTONE DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Bottom Stacked':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'JACK'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'SKILLET'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'ASTEROID'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'GRAVESTONE DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Bottom Semi-Stacked':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'PLUMP DOJI'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'LONG-LEG DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Centered':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'PLUMP DOJI'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'LONG-LEG DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Top Semi-Stacked':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'PLUMP DOJI'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'LONG-LEG DOJI'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Top Stacked':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'BOOST'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'BRAKE'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'BRAKE'
                    else:
                        Read = D.iloc[i,8]
                elif D.iloc[i,9] == 'Top Saturated':
                    if D.iloc[i,8] == 'Shark':
                        Read = 'MARIBOZU'
                    elif D.iloc[i,8] == 'Horse':
                        Read = 'TUBE'
                    elif D.iloc[i,8] == 'Dog':
                        Read = 'BOOST'
                    elif D.iloc[i,8] == 'Cat':
                        Read = 'GLIDE'
                    elif D.iloc[i,8] == 'Frog':
                        Read = 'BRAKE'
                    elif D.iloc[i,8] == 'Doji':
                        Read = 'BRAKE'
                    else:
                        Read = D.iloc[i,8]
                else:
                    Read = D.iloc[i,8]
            else:
                Read = D.iloc[i,8]
            i = i + 1
            READING.append(Read)
        D['READING'] = READING

        READING2=[]
        READING2.append(0)
        jl = l - 1
        linjj = np.linspace(1,jl,num=jl)
        i = 1
        for t in linjj: 
            ii = i - 1
            if D.iloc[i,10] < 0:
                if D.iloc[ii,7] == 'Bearish':
                    if D.iloc[i,3] > D.iloc[ii,1]:
                        if D.iloc[ii,11] == 'BRAKE':
                            if D.iloc[i,7] == 'Bullish':
                                if D.iloc[i,11] == 'MARIBOZU':
                                    Read2 = 'BULLISH ENGULFING'
                                elif D.iloc[i,11] == 'TUBE':
                                    Read2 = 'BULLISH ENGULFING'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        elif D.iloc[ii,11] == 'GLIDE':
                            if D.iloc[i,7] == 'Bullish':
                                if D.iloc[i,11] == 'MARIBOZU':
                                    Read2 = 'BULLISH ENGULFING'
                                elif D.iloc[i,11] == 'TUBE':
                                    Read2 = 'BULLISH ENGULFING'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        elif D.iloc[ii,11] == 'PLUMP DOJI':
                            if D.iloc[i,7] == 'Bullish':
                                if D.iloc[i,11] == 'MARIBOZU':
                                    Read2 = 'BULLISH ENGULFING'
                                elif D.iloc[i,11] == 'TUBE':
                                    Read2 = 'BULLISH ENGULFING'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        elif D.iloc[ii,11] == 'LONG-LEG DOJI':
                            if D.iloc[i,7] == 'Bullish':
                                if D.iloc[i,11] == 'MARIBOZU':
                                    Read2 = 'BULLISH ENGULFING'
                                elif D.iloc[i,11] == 'TUBE':
                                    Read2 = 'BULLISH ENGULFING'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        else:
                            Read2 = 0
                    elif D.iloc[i,0] == D.iloc[ii,3]:
                        if D.iloc[i,2] == D.iloc[ii,2]:
                            if D.iloc[i,7] == 'Bullish':
                                if D.iloc[i,3] > D.iloc[ii,0]:
                                    Read2 = 'TWEEZERS BOTTOM'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        else:
                            Read2 = 0
                    elif D.iloc[i,3] > (D.iloc[ii,0]+D.iloc[ii,3])/2:
                        if D.iloc[i,0] < D.iloc[ii,3]:
                            if D.iloc[ii,7] == 'Bullish':
                                Read2 = 'PIERCING PATTERN'
                            else:
                                Read2 = 0
                        else:
                            Read2 = 0
                    else:
                        Read2 = 0
                else:
                    Read2 = 0
            elif D.iloc[i,10] > 0:
                if D.iloc[ii,7] == 'Bullish':
                    if D.iloc[i,3] < D.iloc[ii,2]:
                        if D.iloc[ii,11] == 'BRAKE':
                            if D.iloc[i,7] == 'Bearish':
                                if D.iloc[i,11] == 'MARIBOZU':
                                    Read2 = 'BEARISH ENGULFING'
                                elif D.iloc[i,11] == 'TUBE':
                                    Read2 = 'BEARISH ENGULFING'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        elif D.iloc[ii,11] == 'GLIDE':
                            if D.iloc[i,7] == 'Bearish':
                                if D.iloc[i,11] == 'MARIBOZU':
                                    Read2 = 'BEARISH ENGULFING'
                                elif D.iloc[i,11] == 'TUBE':
                                    Read2 = 'BEARISH ENGULFING'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        elif D.iloc[ii,11] == 'PLUMP DOJI':
                            if D.iloc[i,7] == 'Bearish':
                                if D.iloc[i,11] == 'MARIBOZU':
                                    Read2 = 'BEARISH ENGULFING'
                                elif D.iloc[i,11] == 'TUBE':
                                    Read2 = 'BEARISH ENGULFING'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        elif D.iloc[ii,11] == 'LONG-LEG DOJI':
                            if D.iloc[i,7] == 'Bearish':
                                if D.iloc[i,11] == 'MARIBOZU':
                                    Read2 = 'BEARISH ENGULFING'
                                elif D.iloc[i,11] == 'TUBE':
                                    Read2 = 'BEARISH ENGULFING'
                                else:
                                    Read2 = 0
                            else:
                                Read2 = 0
                        else:
                            Read2 = 0
                    else:
                        Read2 = 0
                elif D.iloc[i,3] == D.iloc[ii,0]:
                    if D.iloc[i,1] == D.iloc[ii,1]:
                        if D.iloc[i,7] == 'Bearish':
                            if D.iloc[i,3] < D.iloc[ii,0]:
                                Read2 = 'TWEEZERS TOP'
                            else:
                                Read2 = 0
                        else:
                            Read2 = 0
                    else:
                        Read2 = 0
                elif D.iloc[i,3] < (D.iloc[ii,0]+D.iloc[ii,3])/2:
                    if D.iloc[i,0] > D.iloc[ii,3]:
                        if D.iloc[ii,7] == 'Bearish':
                            Read2 = 'DARK CLOUD COVER'
                        else:
                            Read2 = 0
                    else:
                        Read2 = 0
                else:
                    Read2 = 0
            else:
                Read2 = 0
            i = i + 1
            READING2.append(Read2)
        D['READING2'] = READING2

        P = D.iloc[598,:]

        OTESTLVL = 0
        for u in levels:
            if abs(P[0]-u) <= CM:
                OTESTLVL = u

        CTESTLVL = 0
        for u in levels:
            if abs(P[3]-u) <= CM:
                CTESTLVL = u

        BREAKLVL = 0
        for u in levels:
            if P[7] == 'Bullish':
                if P[3] > (u+CM):
                    if P[0] < u:
                        BREAKLVL = u
                    elif OTESTLVL == u:
                        BREAKLVL = u
            elif P[7] == 'Bearish':
                if P[3] < (u-CM):
                    if P[0] > u:
                        BREAKLVL = u
                    elif OTESTLVL == u:
                        BREAKLVL = u
      
        F = mt5.copy_rates_from_pos(x, mt5.TIMEFRAME_M15, 0, 200)
        x1 = np.linspace(1, 200, num=200)
        y1 = F['close']
        slope, intercept, r_value, p_value, std_err = stats.linregress(x1,y1)
        wholeslope = slope

        if wholeslope > 0:
            if P[10] > 0:
                ditrend = 1
            elif P[10] < 0:
                ditrend = -1
            else:
                ditrend = 0
        elif wholeslope < 0:
            if P[10] < 0:
                ditrend = 1
            elif P[10] > 0:
                ditrend = -1
            else:
                ditrend = 0
        else:
            ditrend = 0

        if P[7] == 'Bullish':
            if P[10] > 0:
                dstrend = 1
            elif P[10] < 0:
                dstrend = -1
            else:
                dstrend = 0
        elif P[7] == 'Bearish':
            if P[10] < 0:
                dstrend = 1
            elif P[10] > 0:
                dstrend = -1
            else:
                dstrend = 0
        else:
            dstrend = 0

        ypa = ['JACK', 'GLIDE']
        grpa = ['MARIBOZU', 'TUBE', 'BOOST']
        goldpa = ['HAMMER', 'SHOOTING STAR', 'DRAGONFLY DOJI', 'GRAVESTONE DOJI', 'LONG-LEG DOJI']
        silvpa = ['PLUMP DOJI', 'MALLET', 'ASTEROID', 'DIPPER', 'SKILLET']
        goldpa2 = ['BULLISH ENGULFING', 'BEARISH ENGULFING', 'TWEEZERS TOP', 'TWEEZERS BOTTOM', 'DARK CLOUD COVER', 'PIERCING PATTERN']

        color = 'white'
        if BREAKLVL != 0:
            if CTESTLVL == 0:
                if dstrend == 1:
                    color = 'pearl'
                elif dstrend == -1:
                    color = 'black'
        elif BREAKLVL == 0:
            if CTESTLVL != 0:
                if OTESTLVL == CTESTLVL:
                    if P[12] == 0:
                        color = 'gray'
                elif OTESTLVL == 0:
                    if P[12] == 0:
                        if dstrend == 1:
                            color = 'blue'
                        elif dstrend == -1:
                            color = 'purple'
                    elif P[12] != 0:
                        for ugo2 in goldpa2:
                            if P[12] == ugo2:
                                color = 'gold'
                            elif P[12] == 0:
                                if P[11] != 0:
                                    for ugo in goldpa:
                                        if P[11] == ugo:
                                            color = 'gold'
                elif OTESTLVL == 0:
                    if P[12] == 0:
                        for uy in ypa:
                            if P[11] == uy:
                                if dstrend == 1:
                                    color = 'yellow'
                                elif dstrend == -1:
                                    color = 'orange'
                        for ug in grpa:
                            if P[11] == ug:
                                if dstrend == 1:
                                    color = 'green'
                                elif dstrend == -1:
                                    color = 'red'
        
        if color == 'purple':
            coltrade = 'TRADE'
        elif color == 'gold':
            coltrade = 'TRADE'
        else:
            coltrade = 0
                
        if coltrade == 'TRADE':
            
            Hrates = mt5.copy_rates_from_pos(x, mt5.TIMEFRAME_H2, 0, 25)
            H = pd.DataFrame(Hrates)
            hlin = np.linspace(1,25,num=25)
            
            SLOPE = []
            i = 0
            for t in hlin:
                ii = i - 1
                if i == 0:
                    SLOPE.append(0)
                else:
                    slope = H.iloc[i,4] - H.iloc[ii,4]
                    SLOPE.append(slope)
                i = i + 1

            SLOPE2 = []
            i = 0
            for t in hlin:
                ii = i - 1
                if i == 0:
                    SLOPE2.append(0)
                else:
                    slope2 = SLOPE[i] - SLOPE[ii]
                    SLOPE2.append(slope2)
                i = i + 1

            CONCAVE = []
            i = 0
            for t in hlin:
                if SLOPE2[i] == 0:
                    CONCAVE.append('INFL')
                elif SLOPE2[i] > 0:
                    CONCAVE.append('UP')
                else:
                    CONCAVE.append('DOWN')
                i = i + 1

            AXCONCAVE = CONCAVE[-1]

            if P[10] > 0:
                if AXCONCAVE == 'UP':
                    contrade = 'TRADE'
                else:
                    contrade = 0
            elif P[10] < 0:
                if AXCONCAVE == 'DOWN':
                    contrade = 'TRADE'
                else:
                    contrade = 0
            else:
                contrade = 0

            if contrade == 'TRADE':
                
                if P[10] > 0:
                    position = 'LONG'
                elif P[10] < 0:
                    position = 'SHORT'
                else:
                    position = 0

                if position == 'LONG':
                    entry = CTESTLVL + CM
                elif position == 'SHORT':
                    entry = CTESTLVL - CM
                else:
                    entry = 0

                cend = int(len(levels)-1)
                if position == 'LONG':
                    clindex = levels.index(CTESTLVL)
                    tpindex = int(clindex - 1)
                    slindex = int(clindex + 1)
                    if clindex == 0:
                        stoploss = levels[slindex]
                        sldist = CTESTLVL - stoploss
                        takeprofit = CTESTLVL + sldist
                    elif clindex == cend:
                        takeprofit = levels[tpindex]
                        tpdist = takeprofit - CTESTLVL
                        stoploss = CTESTLVL - tpdist
                    else:
                        takeprofit = levels[tpindex]
                        stoploss = levels[slindex]
                elif position == 'SHORT':
                    clindex = levels.index(CTESTLVL)
                    tpindex = int(clindex + 1)
                    slindex = int(clindex - 1)
                    if clindex == 0:
                        takeprofit = levels[tpindex]
                        tpdist = CTESTLVL - takeprofit
                        stoploss = CTESTLVL + tpdist
                    elif clindex == cend:
                        stoploss = levels[slindex]
                        sldist = stoploss - CTESTLVL
                        takeprofit = CTESTLVL - sldist
                    else:
                        takeprofit = levels[tpindex]
                        stoploss = levels[slindex]
                else:
                    takeprofit = 0
                    stoploss = 0
                
                shrink = 0.90

                if position == 'LONG':
                    tpdist = takeprofit - entry
                    takeprofit = entry + tpdist*shrink
                elif position == 'SHORT':
                    tpdist = entry - takeprofit
                    takeprofit = entry - tpdist*shrink

                if position == 'LONG':
                    tpdist = takeprofit - entry
                    sldist = entry - stoploss
                    if sldist > tpdist:
                        stoploss = entry - tpdist
                elif position == 'SHORT':
                    tpdist = entry - takeprofit
                    sldist = stoploss - entry
                    if sldist > tpdist:
                        stoploss = entry + tpdist
                
                prp = (x,position,entry,takeprofit,stoploss,CM)
                purp.append(prp)

    purps = pd.DataFrame(purp, columns =['x','position','entry','takeprofit','stoploss','CM']) 
        
    purps['RATE'] = 0
    purps['RATE2'] = 0
    purps['spy'] = "YES"
    purpcnt = int(purps['x'].count())
    purplin = np.linspace(1,purpcnt,num=purpcnt)
    print(purps)
    
    end = dt.now()
    elapsed = end - start
    elapsed = elapsed.total_seconds()
    elapsed = str(elapsed)
    timer = elapsed + '   seconds'
    print(timer)
    
    watchers = purps['spy']
    ite = 0
    while any(s == "YES" for s in watchers):
        i = 0
        for t in purplin:
            if purps.iloc[i,8] == "YES":
                Xpair = purps.iloc[i,0]
                position = purps.iloc[i,1]
                entry = purps.iloc[i,2]
                takeprofit = purps.iloc[i,3]
                stoploss = purps.iloc[i,4]
                CM = purps.iloc[i,5]
                k1 = purps.iloc[i,6]
                k2 = purps.iloc[i,7]
                k3 = purps.iloc[i,8]
                RATE, RATE2, spy = brutus2(Xpair,position,entry,takeprofit,stoploss,CM,4,1,k1,k2,k3)
                print(Xpair,RATE,RATE2,spy)
                purps.iloc[i,6] = RATE
                purps.iloc[i,7] = RATE2
                purps.iloc[i,8] = spy
            i = i + 1
        watchers = purps['spy']
        if ite == 28:
            break
        ite = ite + 1
        time.sleep(10)
    
    end = dt.now()
    elapsed = end - start
    elapsed = elapsed.total_seconds()
    elapsed = str(elapsed)
    timer = elapsed + '   seconds'
    print(timer)
    playsound('C:/Users/joeca/Desktop/Finance/FOREX/Hercules_Prototype_Mark_II/MP3s/done.mp3')

# %%
#iterator = 0
#
#while iterator <= 11:
#    p = Process(target=brutus, args=())
#    p.start()
#    brutus()
#    iterator = iterator + 1
#    time.sleep(3)
#
#p.join()

# %%
#brutus()

# %%
t2 = 0
while True:
    Drates = mt5.copy_rates_from_pos("EURUSD", mt5.TIMEFRAME_M5, 0, 1)
    D = Drates[0]
    t = D[0]
    if t2 != 0:
        if t != t2:
            print("BRUTUS Launched")
            brutus()
    t2 = t
    time.sleep(5)
# Out:
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 18.295362   seconds
# 18.295362   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.724413   seconds
# 14.725422   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.571673   seconds
# 15.572671   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.975408   seconds
# 14.97641   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.813988   seconds
# 14.813988   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.274979   seconds
# 14.275977   seconds
# BRUTUS Launched
#         x position       entry  takeprofit    stoploss        CM  RATE  RATE2  \
# 0  USDJPY     LONG  107.870712  107.869171  107.872252  0.014712     0      0
#
#    spy
# 0  YES
# 14.479634   seconds
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDJPY', volume=3.5, price=107.854, stoplimit=0.0, sl=107.87225216666667, tp=107.86917116666666, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BRUTUS Mark V', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDJPY
#        traderequest: volume=3.5
#        traderequest: price=107.854
#        traderequest: stoplimit=0.0
#        traderequest: sl=107.87225216666667
#        traderequest: tp=107.86917116666666
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS Mark V
#        traderequest: position=0
#        traderequest: position_by=0
# USDJPY 1 1 NO
# 24.495489   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.909909   seconds
# 14.909909   seconds
# BRUTUS Launched
#         x position       entry  takeprofit    stoploss        CM  RATE  RATE2  \
# 0  USDJPY     LONG  107.824738  107.844774  107.804703  0.014738     0      0
#
#    spy
# 0  YES
# 14.439983   seconds
# USDJPY 1 1 NO
# 24.595204   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.809443   seconds
# 14.809443   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.908446   seconds
# 14.908446   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.457411   seconds
# 14.457411   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.77923   seconds
# 14.780235   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  GBPUSD    SHORT  1.226426    1.226115  1.226737  0.000304     0      0  YES
# 1  NZDCAD    SHORT  0.850791    0.850529  0.851052  0.000209     0      0  YES
# 16.330283   seconds
# GBPUSD 0 0 YES
# NZDCAD 1 0 YES
# GBPUSD 0 0 YES
# NZDCAD 2 0 YES
# GBPUSD 0 0 YES
# NZDCAD 0 0 YES
# GBPUSD 0 0 YES
# NZDCAD 1 0 YES
# GBPUSD 0 0 YES
# NZDCAD 2 0 YES
# GBPUSD 0 0 YES
# NZDCAD 3 0 YES
# GBPUSD 0 0 YES
# NZDCAD 4 0 NO
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# GBPUSD 0 0 YES
# 296.605434   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.590408   seconds
# 15.590408   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.218745   seconds
# 15.218745   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.852541   seconds
# 14.852541   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.745119   seconds
# 15.745119   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.514998   seconds
# 14.514998   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  AUDCAD    SHORT  0.910264    0.909837  0.910690  0.000216     0      0  YES
# 1  AUDNZD    SHORT  1.070442    1.070062  1.070822  0.000188     0      0  YES
# 2  GBPAUD     LONG  1.853117    1.854947  1.851287  0.000497     0      0  YES
# 14.706599   seconds
# AUDCAD 0 0 YES
# AUDNZD 0 0 YES
# GBPAUD 1 1 NO
# AUDCAD 0 0 YES
# AUDNZD 0 0 YES
# AUDCAD 0 0 YES
# AUDNZD 0 0 YES
# AUDCAD 0 0 YES
# AUDNZD 0 0 YES
# AUDCAD 0 0 YES
# AUDNZD 0 0 YES
# AUDCAD 0 0 YES
# AUDNZD 0 0 YES
# AUDCAD 0 0 YES
# AUDNZD 0 0 YES
# AUDCAD 0 0 YES
# AUDNZD 0 0 YES
# AUDCAD 1 0 YES
# AUDNZD 0 0 YES
# AUDCAD 2 0 YES
# AUDNZD 0 0 YES
# AUDCAD 3 0 YES
# AUDNZD 0 0 YES
# AUDCAD 4 0 NO
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 1 0 YES
# 295.107108   seconds
# BRUTUS Launched
#         x position       entry  takeprofit    stoploss        CM  RATE  RATE2  \
# 0  AUDJPY    SHORT   71.348020   71.140102   71.536000  0.026980     0      0
# 1  GBPJPY    SHORT  132.227435  132.135244  132.319627  0.035565     0      0
# 2  GBPUSD    SHORT    1.226425    1.226115    1.226736  0.000305     0      0
# 3  USDCAD     LONG    1.374934    1.384308    1.368970  0.000324     0      0
#
#    spy
# 0  YES
# 1  YES
# 2  YES
# 3  YES
# 15.911071   seconds
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# USDCAD 1 1 NO
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# AUDJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPUSD 0 0 YES
# 296.367381   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  AUDCAD    SHORT  0.910264    0.909837  0.910691  0.000216     0      0  YES
# 15.342356   seconds
# AUDCAD 1 0 YES
# AUDCAD 2 0 YES
# AUDCAD 3 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 1 0 YES
# AUDCAD 2 0 YES
# AUDCAD 3 0 YES
# AUDCAD 4 0 NO
# 105.499643   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.705537   seconds
# 15.705537   seconds
# BRUTUS Launched
#         x position       entry  takeprofit    stoploss        CM  RATE  RATE2  \
# 0  EURCHF    SHORT    1.067411    1.066123    1.068100  0.000169     0      0
# 1  GBPJPY    SHORT  132.227218  132.135222  132.319215  0.035782     0      0
#
#    spy
# 0  YES
# 1  YES
# 23.47221   seconds
# EURCHF 0 0 YES
# GBPJPY 0 0 YES
# EURCHF 0 0 YES
# GBPJPY 0 0 YES
# EURCHF 0 0 YES
# GBPJPY 0 0 YES
# EURCHF 0 0 YES
# GBPJPY 0 0 YES
# EURCHF 1 0 YES
# GBPJPY 0 0 YES
# EURCHF 2 0 YES
# GBPJPY 0 0 YES
# EURCHF 3 0 YES
# GBPJPY 0 0 YES
# EURCHF 4 0 NO
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 1 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 1 0 YES
# GBPJPY 2 0 YES
# 303.758426   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.67988   seconds
# 14.680842   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  EURNZD     LONG  1.782342    1.783825  1.780858  0.000481     0      0  YES
# 1  NZDUSD    SHORT  0.618914    0.615697  0.620360  0.000206     0      0  YES
# 15.459496   seconds
# EURNZD 1 1 NO
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 1 0 YES
# NZDUSD 2 0 YES
# 295.69444   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.795711   seconds
# 14.795711   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.145744   seconds
# 15.145744   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  NZDCHF    SHORT  0.599061    0.597710  0.600412  0.000189     0      0  YES
# 1  NZDUSD    SHORT  0.618915    0.615697  0.620360  0.000205     0      0  YES
# 15.51309   seconds
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 0 0 YES
# NZDUSD 0 0 YES
# NZDCHF 1 0 YES
# NZDUSD 0 0 YES
# NZDCHF 2 0 YES
# NZDUSD 1 0 YES
# NZDCHF 3 0 YES
# NZDUSD 2 0 YES
# NZDCHF 4 0 NO
# NZDUSD 0 0 YES
# NZDUSD 0 0 YES
# NZDUSD 1 0 YES
# NZDUSD 2 0 YES
# NZDUSD 3 0 YES
# NZDUSD 4 0 NO
# 205.904778   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.581069   seconds
# 15.581069   seconds
# BRUTUS Launched
#         x position       entry  takeprofit    stoploss        CM  RATE  RATE2  \
# 0  NZDCHF    SHORT    0.599061    0.597710    0.600412  0.000189     0      0
# 1  NZDJPY    SHORT   66.749197   66.353020   66.834000  0.023803     0      0
# 2  USDJPY    SHORT  107.831845  107.812185  107.851505  0.015155     0      0
#
#    spy
# 0  YES
# 1  YES
# 2  YES
# 15.17362   seconds
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 0 0 YES
# NZDJPY 0 0 YES
# USDJPY 0 0 YES
# NZDCHF 1 0 YES
# NZDJPY 1 0 YES
# USDJPY 0 0 YES
# NZDCHF 2 0 YES
# NZDJPY 2 0 YES
# USDJPY 0 0 YES
# NZDCHF 3 0 YES
# NZDJPY 3 0 YES
# USDJPY 0 0 YES
# NZDCHF 4 0 NO
# NZDJPY 4 0 NO
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# USDJPY 0 0 YES
# 295.631389   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.470531   seconds
# 15.470531   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.419281   seconds
# 15.420293   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.568604   seconds
# 15.569602   seconds
# BRUTUS Launched
#         x position       entry  takeprofit    stoploss        CM  RATE  RATE2  \
# 0  GBPJPY    SHORT  132.227183  132.135218  132.319148  0.035817     0      0
#
#    spy
# 0  YES
# 15.637606   seconds
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# GBPJPY 0 0 YES
# 295.739487   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  NZDCHF    SHORT  0.599061     0.59771  0.600412  0.000189     0      0  YES
# 15.090713   seconds
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 1 0 YES
# NZDCHF 2 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 0 0 YES
# NZDCHF 1 0 YES
# NZDCHF 2 0 YES
# NZDCHF 3 0 YES
# NZDCHF 4 0 NO
# 215.31126   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.183795   seconds
# 15.184798   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 16.107919   seconds
# 16.107919   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  GBPCAD    SHORT  1.686925    1.683347  1.690502  0.000395     0      0  YES
# 14.762501   seconds
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 1 0 YES
# GBPCAD 2 0 YES
# GBPCAD 0 0 YES
# GBPCAD 1 0 YES
# GBPCAD 2 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# GBPCAD 0 0 YES
# 294.980832   seconds
# BRUTUS Launched
#         x position      entry  takeprofit   stoploss        CM  RATE  RATE2  \
# 0  AUDJPY     LONG  71.401648   71.522565  71.280732  0.026648     0      0
#
#    spy
# 0  YES
# 14.072791   seconds
# AUDJPY 1 1 NO
# 24.388014   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.068544   seconds
# 14.068544   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.581364   seconds
# 14.581364   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  AUDCAD    SHORT  0.910266    0.909838  0.910695  0.000214     0      0  YES
# 1  EURGBP     LONG  0.898375    0.899351  0.897398  0.000185     0      0  YES
# 14.470918   seconds
# AUDCAD 0 0 YES
# EURGBP 1 1 NO
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# AUDCAD 0 0 YES
# 295.346828   seconds
# BRUTUS Launched
#         x position       entry  takeprofit    stoploss        CM  RATE  RATE2  \
# 0  EURJPY     LONG  118.814703  118.802370  118.827036  0.027703     0      0
# 1  NZDCAD    SHORT    0.850791    0.850529    0.851054  0.000209     0      0
#
#    spy
# 0  YES
# 1  YES
# 15.442271   seconds
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURJPY', volume=0.44, price=118.801, stoplimit=0.0, sl=118.82703633333335, tp=118.80237033333333, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BRUTUS Mark V', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURJPY
#        traderequest: volume=0.44
#        traderequest: price=118.801
#        traderequest: stoplimit=0.0
#        traderequest: sl=118.82703633333335
#        traderequest: tp=118.80237033333333
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS Mark V
#        traderequest: position=0
#        traderequest: position_by=0
# EURJPY 1 1 NO
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# NZDCAD 0 0 YES
# 295.725469   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.554952   seconds
# 14.555949   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.838674   seconds
# 14.838674   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.477674   seconds
# 14.477674   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.379158   seconds
# 15.379158   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.245982   seconds
# 14.245982   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.857367   seconds
# 14.857367   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.755061   seconds
# 14.755061   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.864001   seconds
# 14.864001   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.131052   seconds
# 14.132049   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  AUDNZD    SHORT  1.067772    1.067554  1.067991  0.000188     0      0  YES
# 1  EURGBP     LONG  0.898375    0.899351  0.897398  0.000185     0      0  YES
# 14.455656   seconds
# AUDNZD 0 0 YES
# EURGBP 1 1 NO
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 1 0 YES
# AUDNZD 2 0 YES
# AUDNZD 3 0 YES
# AUDNZD 4 0 NO
# 95.145955   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.600325   seconds
# 14.600325   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  EURGBP     LONG  0.898375    0.899352  0.897399  0.000185     0      0  YES
# 1  NZDCAD    SHORT  0.850792    0.850529  0.851055  0.000208     0      0  YES
# 14.417646   seconds
# EURGBP 1 1 NO
# NZDCAD 1 0 YES
# NZDCAD 2 0 YES
# NZDCAD 3 0 YES
# NZDCAD 4 0 NO
# 54.907406   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.298111   seconds
# 15.298111   seconds
# BRUTUS Launched
#         x position      entry  takeprofit   stoploss        CM  RATE  RATE2  \
# 0  AUDJPY    SHORT  71.046223   70.966822  71.117000  0.026777     0      0
# 1  AUDUSD    SHORT   0.659287    0.658660   0.659915  0.000233     0      0
# 2  EURAUD     LONG   1.670112    1.672864   1.667361  0.000462     0      0
#
#    spy
# 0  YES
# 1  YES
# 2  YES
# 14.639457   seconds
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# EURAUD 1 1 NO
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# AUDJPY 0 0 YES
# AUDUSD 0 0 YES
# 295.195149   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.526789   seconds
# 14.526789   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.956626   seconds
# 14.95762   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  AUDNZD    SHORT  1.067313    1.066671   1.06753  0.000187     0      0  YES
# 15.354049   seconds
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# AUDNZD 0 0 YES
# 295.616356   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.824802   seconds
# 14.824802   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.694993   seconds
# 14.694993   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.799824   seconds
# 14.799824   seconds
# BRUTUS Launched
#         x position      entry  takeprofit   stoploss        CM  RATE  RATE2  \
# 0  CADJPY     LONG  78.289757   78.475376  78.104138  0.021757     0      0
#
#    spy
# 0  YES
# 14.413144   seconds
# CADJPY 1 1 NO
# 24.542964   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.877145   seconds
# 14.877145   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.360508   seconds
# 15.360508   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.23522   seconds
# 14.23522   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.154528   seconds
# 14.155525   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  GBPAUD    SHORT  1.854658    1.852824  1.856493  0.000492     0      0  YES
# 14.388134   seconds
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# GBPAUD 0 0 YES
# 294.803118   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  AUDUSD     LONG  0.660801    0.663383   0.65952  0.000231     0      0  YES
# 14.270338   seconds
# AUDUSD 1 1 NO
# 24.406642   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.36015   seconds
# 15.36015   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.068783   seconds
# 14.068783   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.489486   seconds
# 14.489486   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.418653   seconds
# 15.418653   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.401334   seconds
# 14.401334   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.177889   seconds
# 14.178892   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.397487   seconds
# 14.397487   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.187148   seconds
# 14.187148   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  AUDCAD     LONG  0.911176    0.911765  0.910588  0.000216     0      0  YES
# 14.595614   seconds
# AUDCAD 1 1 NO
# 24.913015   seconds
# BRUTUS Launched
#         x position       entry  takeprofit    stoploss        CM  RATE  RATE2  \
# 0  EURJPY     LONG  118.899998     118.972  118.827997  0.027998     0      0
#
#    spy
# 0  YES
# 14.33287   seconds
# EURJPY 1 1 NO
# 24.469905   seconds
# BRUTUS Launched
#         x position      entry  takeprofit    stoploss       CM  RATE  RATE2  \
# 0  GBPJPY     LONG  132.41394  132.470694  132.357186  0.03594     0      0
#
#    spy
# 0  YES
# 15.080995   seconds
# GBPJPY 1 1 NO
# 25.401247   seconds
# BRUTUS Launched
#         x position      entry  takeprofit   stoploss        CM  RATE  RATE2  \
# 0  NZDJPY     LONG  66.857657   67.153166  66.773000  0.023657     0      0
# 1  USDCAD    SHORT   1.374281    1.369501   1.379061  0.000329     0      0
#
#    spy
# 0  YES
# 1  YES
# 14.860657   seconds
# NZDJPY 1 1 NO
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# USDCAD 0 0 YES
# 295.316413   seconds
# BRUTUS Launched
#         x position      entry  takeprofit   stoploss        CM  RATE  RATE2  \
# 0  AUDJPY     LONG  71.402133   71.522613  71.281653  0.027133     0      0
# 1  GBPUSD     LONG   1.227038    1.227823   1.226254  0.000308     0      0
#
#    spy
# 0  YES
# 1  YES
# 15.054774   seconds
# AUDJPY 1 1 NO
# GBPUSD 0 1 NO
# 25.607838   seconds
# BRUTUS Launched
#         x position      entry  takeprofit   stoploss        CM  RATE  RATE2  \
# 0  EURAUD    SHORT   1.664793    1.662630   1.666520  0.000467     0      0
# 1  NZDJPY     LONG  66.796757   66.830276  66.763238  0.023757     0      0
#
#    spy
# 0  YES
# 1  YES
# 14.407484   seconds
# EURAUD 0 0 YES
# NZDJPY 1 1 NO
# EURAUD 0 0 YES
# EURAUD 0 0 YES
# EURAUD 0 0 YES
# EURAUD 0 0 YES
# EURAUD 0 0 YES
# EURAUD 1 0 YES
# EURAUD 2 0 YES
# EURAUD 3 0 YES
# EURAUD 4 0 NO
# 114.931673   seconds
# BRUTUS Launched
#         x position     entry  takeprofit  stoploss        CM  RATE  RATE2  spy
# 0  NZDUSD     LONG  0.619326    0.620257  0.618395  0.000206     0      0  YES
# 14.556673   seconds
# NZDUSD 1 1 NO
# 24.719832   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.862678   seconds
# 14.862678   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 20.311579   seconds
# 20.312563   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.390401   seconds
# 14.390401   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.593238   seconds
# 15.594234   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 16.018251   seconds
# 16.018251   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 15.104658   seconds
# 15.104658   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.706996   seconds
# 14.706996   seconds
# BRUTUS Launched
# Empty DataFrame
# Columns: [x, position, entry, takeprofit, stoploss, CM, RATE, RATE2, spy]
# Index: []
# 14.605853   seconds
# 14.605853   seconds
# BRUTUS Launched
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d3810db2dae9> in <module>
#       7         if t != t2:
#       8             print("BRUTUS Launched")
# ----> 9             brutus()
#      10     t2 = t
#      11     time.sleep(5)
#
# <ipython-input-7-7c8db7c6f45f> in brutus()
#     516         OTESTLVL = 0
#     517         for u in levels:
# --> 518             if abs(P[0]-u) <= CM:
#     519                 OTESTLVL = u
#     520
#
# ~\.conda\envs\py38\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\.conda\envs\py38\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4376         # use this, e.g. DatetimeIndex
#    4377         # Things like `Series._get_value` (via .at) pass the EA directly here.
# -> 4378         s = extract_array(series, extract_numpy=True)
#    4379         if isinstance(s, ExtensionArray):
#    4380             if is_scalar(key):
#
# ~\.conda\envs\py38\lib\site-packages\pandas\core\construction.py in extract_array(obj, extract_numpy)
#     378     """
#     379     if isinstance(obj, (ABCIndexClass, ABCSeries)):
# --> 380         obj = obj.array
#     381
#     382     if extract_numpy and isinstance(obj, ABCPandasArray):
#
# ~\.conda\envs\py38\lib\site-packages\pandas\core\series.py in array(self)
#     516     @property
#     517     def array(self) -> ExtensionArray:
# --> 518         return self._data._block.array_values()
#     519
#     520     def _internal_get_values(self):
#
# KeyboardInterrupt:

# %%
mt5.shutdown()
